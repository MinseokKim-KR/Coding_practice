# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import os
## Chrome의 경우 | 아까 받은 chromedriver의 위치를 지정해준다.
driver = webdriver.Chrome('./chromedriver')
driver.get('https://mirrorprotocol.app/#/trade')


## url에 접근한다.
time.sleep(6)
soup = BeautifulSoup(driver.page_source, 'html.parser')

stocks = soup.select('#mirror > div > div.Container_container__lHqDY > article > div > table > tbody > tr')
index = ['time']
premium = []
for stock in stocks[1:]:
    name = stock.select_one('td:nth-child(1) > article > header > h1').text
    price = float(stock.select_one('td:nth-child(4) > span').text.replace('%',''))
    # row = {
    #     'name': name,
    #     'Primeum': price
    # }
    # print(name, price)
    index.append(name)
    premium.append(price)
# Out:
# C:\Users\kimis\AppData\Local\Temp/ipykernel_17372/626370209.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')

# %%
df = pd.DataFrame(data=premium, index=index)

# %%
df
# Out:
#             0
# mAAPL    0.05
# mABNB    2.96
# mAMD     2.05
# mAMZN    1.69
# mARKK    6.50
# mBABA    2.00
# mBTC     3.80
# mCOIN    5.73
# mDOT     5.90
# mETH     3.18
# mFB      5.48
# mGLXY   11.40
# mGOOGL   3.09
# mGS      1.86
# mHOOD    6.19
# mIAU     0.34
# mJNJ     2.78
# mKO      2.26
# mMSFT    1.18
# mNFLX    2.84
# mNIO     3.59
# mNVDA    6.00
# mPYPL    2.54
# mQQQ     1.06
# mSBUX    2.15
# mSLV     1.58
# mSPY     0.99
# mSQ      5.06
# mTSLA    1.70
# mTWTR    6.58
# mUSO     1.11
# mVIXY    4.41

# %%
df = df.transpose()

# %%
df
# Out:
#    mAAPL  mABNB  mAMD  mAMZN  mARKK  mBABA  mBTC  mCOIN  mDOT  mETH  ...  \
# 0   0.05   2.96  2.05   1.69    6.5    2.0   3.8   5.73   5.9  3.18  ...
#
#    mPYPL  mQQQ  mSBUX  mSLV  mSPY   mSQ  mTSLA  mTWTR  mUSO  mVIXY
# 0   2.54  1.06   2.15  1.58  0.99  5.06    1.7   6.58  1.11   4.41
#
# [1 rows x 32 columns]

# %%
import os
if not os.path.exists('output.csv'):
    df.to_csv('output.csv', index=False, mode='w', encoding='utf-8-sig')
else:
    df.to_csv('output.csv', index=False, mode='a', encoding='utf-8-sig', header=False)

# %%
import datetime
Time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
print(Time)
# Out:
# 2022-01-21 00:19:19

# %%
df = pd.DataFrame(data=premium, columns=index)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17372/2338384166.py in <module>
# ----> 1 df = pd.DataFrame(data=premium, columns=index)
#       2 df
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     709                     )
#     710                 else:
# --> 711                     mgr = ndarray_to_mgr(
#     712                         data,
#     713                         index,
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ...

# %%
index
# Out:
# ['mAAPL',
#  'mABNB',
#  'mAMD',
#  'mAMZN',
#  'mARKK',
#  'mBABA',
#  'mBTC',
#  'mCOIN',
#  'mDOT',
#  'mETH',
#  'mFB',
#  'mGLXY',
#  'mGOOGL',
#  'mGS',
#  'mHOOD',
#  'mIAU',
#  'mJNJ',
#  'mKO',
#  'mMSFT',
#  'mNFLX',
#  'mNIO',
#  'mNVDA',
#  'mPYPL',
#  'mQQQ',
#  'mSBUX',
#  'mSLV',
#  'mSPY',
#  'mSQ',
#  'mTSLA',
#  'mTWTR',
#  'mUSO',
#  'mVIXY']

# %%
premium
# Out:
# [0.05,
#  2.96,
#  2.05,
#  1.69,
#  6.5,
#  2.0,
#  3.8,
#  5.73,
#  5.9,
#  3.18,
#  5.48,
#  11.4,
#  3.09,
#  1.86,
#  6.19,
#  0.34,
#  2.78,
#  2.26,
#  1.18,
#  2.84,
#  3.59,
#  6.0,
#  2.54,
#  1.06,
#  2.15,
#  1.58,
#  0.99,
#  5.06,
#  1.7,
#  6.58,
#  1.11,
#  4.41]

# %%
zip_iterator = zip(index, premium)
dic = dict(zip_iterator)

# %%
dic
# Out:
# {'mAAPL': 0.05,
#  'mABNB': 2.96,
#  'mAMD': 2.05,
#  'mAMZN': 1.69,
#  'mARKK': 6.5,
#  'mBABA': 2.0,
#  'mBTC': 3.8,
#  'mCOIN': 5.73,
#  'mDOT': 5.9,
#  'mETH': 3.18,
#  'mFB': 5.48,
#  'mGLXY': 11.4,
#  'mGOOGL': 3.09,
#  'mGS': 1.86,
#  'mHOOD': 6.19,
#  'mIAU': 0.34,
#  'mJNJ': 2.78,
#  'mKO': 2.26,
#  'mMSFT': 1.18,
#  'mNFLX': 2.84,
#  'mNIO': 3.59,
#  'mNVDA': 6.0,
#  'mPYPL': 2.54,
#  'mQQQ': 1.06,
#  'mSBUX': 2.15,
#  'mSLV': 1.58,
#  'mSPY': 0.99,
#  'mSQ': 5.06,
#  'mTSLA': 1.7,
#  'mTWTR': 6.58,
#  'mUSO': 1.11,
#  'mVIXY': 4.41}

# %%
df = pd.DataFrame.from_dict(dic,  orient='index',columns=index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17372/2305488365.py in <module>
# ----> 1 df = pd.DataFrame.from_dict(dic,  orient='index',columns=index)
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1591             raise ValueError("only recognize index or columns for orient")
#    1592
# -> 1593         return cls(data, index=index, columns=columns, dtype=dtype)
#    1594
#    1595     def to_numpy(
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     709                     )
#     710                 else:
# --> 711                     mgr = ndarray_to_mgr(
#     712                         data,
#     713                         index,
#
# ...

# %%
df = pd.DataFrame(dic)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17372/4110689157.py in <module>
# ----> 1 df = pd.DataFrame(dic)
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
# ...

# %%
df
# Out:
#             0
# mAAPL    0.05
# mABNB    2.96
# mAMD     2.05
# mAMZN    1.69
# mARKK    6.50
# mBABA    2.00
# mBTC     3.80
# mCOIN    5.73
# mDOT     5.90
# mETH     3.18
# mFB      5.48
# mGLXY   11.40
# mGOOGL   3.09
# mGS      1.86
# mHOOD    6.19
# mIAU     0.34
# mJNJ     2.78
# mKO      2.26
# mMSFT    1.18
# mNFLX    2.84
# mNIO     3.59
# mNVDA    6.00
# mPYPL    2.54
# mQQQ     1.06
# mSBUX    2.15
# mSLV     1.58
# mSPY     0.99
# mSQ      5.06
# mTSLA    1.70
# mTWTR    6.58
# mUSO     1.11
# mVIXY    4.41

# %%
re_data = [[p] for p in premium]

# %%
re_data
# Out:
# [[0.05],
#  [2.96],
#  [2.05],
#  [1.69],
#  [6.5],
#  [2.0],
#  [3.8],
#  [5.73],
#  [5.9],
#  [3.18],
#  [5.48],
#  [11.4],
#  [3.09],
#  [1.86],
#  [6.19],
#  [0.34],
#  [2.78],
#  [2.26],
#  [1.18],
#  [2.84],
#  [3.59],
#  [6.0],
#  [2.54],
#  [1.06],
#  [2.15],
#  [1.58],
#  [0.99],
#  [5.06],
#  [1.7],
#  [6.58],
#  [1.11],
#  [4.41]]

# %%
df = pd.DataFrame(re_data, columns=index)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\construction.py in _finalize_columns_and_data(content, columns, dtype)
#     905     try:
# --> 906         columns = _validate_or_indexify_columns(contents, columns)
#     907     except AssertionError as err:
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\construction.py in _validate_or_indexify_columns(content, columns)
#     953             # caller's responsibility to check for this...
# --> 954             raise AssertionError(
#     955                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 32 columns passed, passed data had 1 columns
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#             0
# mAAPL    0.05
# mABNB    2.96
# mAMD     2.05
# mAMZN    1.69
# mARKK    6.50
# mBABA    2.00
# mBTC     3.80
# mCOIN    5.73
# mDOT     5.90
# mETH     3.18
# mFB      5.48
# mGLXY   11.40
# mGOOGL   3.09
# mGS      1.86
# mHOOD    6.19
# mIAU     0.34
# mJNJ     2.78
# mKO      2.26
# mMSFT    1.18
# mNFLX    2.84
# mNIO     3.59
# mNVDA    6.00
# mPYPL    2.54
# mQQQ     1.06
# mSBUX    2.15
# mSLV     1.58
# mSPY     0.99
# mSQ      5.06
# mTSLA    1.70
# mTWTR    6.58
# mUSO     1.11
# mVIXY    4.41

# %%
df.transpose()
# Out:
#    mAAPL  mABNB  mAMD  mAMZN  mARKK  mBABA  mBTC  mCOIN  mDOT  mETH  ...  \
# 0   0.05   2.96  2.05   1.69    6.5    2.0   3.8   5.73   5.9  3.18  ...
#
#    mPYPL  mQQQ  mSBUX  mSLV  mSPY   mSQ  mTSLA  mTWTR  mUSO  mVIXY
# 0   2.54  1.06   2.15  1.58  0.99  5.06    1.7   6.58  1.11   4.41
#
# [1 rows x 32 columns]

# %%
df
# Out:
#             0
# mAAPL    0.05
# mABNB    2.96
# mAMD     2.05
# mAMZN    1.69
# mARKK    6.50
# mBABA    2.00
# mBTC     3.80
# mCOIN    5.73
# mDOT     5.90
# mETH     3.18
# mFB      5.48
# mGLXY   11.40
# mGOOGL   3.09
# mGS      1.86
# mHOOD    6.19
# mIAU     0.34
# mJNJ     2.78
# mKO      2.26
# mMSFT    1.18
# mNFLX    2.84
# mNIO     3.59
# mNVDA    6.00
# mPYPL    2.54
# mQQQ     1.06
# mSBUX    2.15
# mSLV     1.58
# mSPY     0.99
# mSQ      5.06
# mTSLA    1.70
# mTWTR    6.58
# mUSO     1.11
# mVIXY    4.41

# %%
names = ['Katie', 'Nik', 'James', 'Evan']
ages = [32, 32, 36, 31]
locations = ['London', 'Toronto', 'Atlanta', 'Madrid']
zipped = list(zip(names, ages, locations))
zipped
# Out:
# [('Katie', 32, 'London'),
#  ('Nik', 32, 'Toronto'),
#  ('James', 36, 'Atlanta'),
#  ('Evan', 31, 'Madrid')]
