# %%
import numpy as np
import pandas as pd

# %%
from typing import Dict
def add_code(
    df: pd.DataFrame,
    d_code: Dict[int, Dict[str, int]], 
    h_code: Dict[int, Dict[str, int]], 
    l_code: Dict[int, Dict[str, int]],
) -> pd.DataFrame:
    
    # Copy input data
    df = df.copy()   

    # D Code
    df['person_prefer_d_1_n'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_1_s'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_1_m'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_1_l'] = df['person_prefer_d_1'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['person_prefer_d_2_n'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_2_s'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_2_m'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_2_l'] = df['person_prefer_d_2'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['person_prefer_d_3_n'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['person_prefer_d_3_s'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['person_prefer_d_3_m'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['person_prefer_d_3_l'] = df['person_prefer_d_3'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    df['contents_attribute_d_n'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 세분류코드'])
    df['contents_attribute_d_s'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 소분류코드'])
    df['contents_attribute_d_m'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 중분류코드'])
    df['contents_attribute_d_l'] = df['contents_attribute_d'].apply(lambda x: d_code[x]['속성 D 대분류코드'])

    # H Code
    df['person_prefer_h_1_l'] = df['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_1_m'] = df['person_prefer_h_1'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    
    df['person_prefer_h_2_l'] = df['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_2_m'] = df['person_prefer_h_2'].apply(lambda x: h_code[x]['속성 H 중분류코드'])
    
    df['person_prefer_h_3_l'] = df['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['person_prefer_h_3_m'] = df['person_prefer_h_3'].apply(lambda x: h_code[x]['속성 H 중분류코드'])

    df['contents_attribute_h_l'] = df['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 대분류코드'])
    df['contents_attribute_h_m'] = df['contents_attribute_h'].apply(lambda x: h_code[x]['속성 H 중분류코드'])

    # L Code
    df['contents_attribute_l_n'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 세분류코드'])
    df['contents_attribute_l_s'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 소분류코드'])
    df['contents_attribute_l_m'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 중분류코드'])
    df['contents_attribute_l_l'] = df['contents_attribute_l'].apply(lambda x: l_code[x]['속성 L 대분류코드'])
    
    return df

# %%
d_code = pd.read_csv('../../220102/DACON/Jobcare_data/속성_D_코드.csv', index_col=0).T.to_dict()
h_code = pd.read_csv('../../220102/DACON/Jobcare_data/속성_H_코드.csv', index_col=0).T.to_dict()
l_code = pd.read_csv('../../220102/DACON/Jobcare_data/속성_L_코드.csv', index_col=0).T.to_dict()

df_train = pd.read_csv('../../220102/DACON/Jobcare_data/train.csv')
df_test = pd.read_csv('../../220102/DACON/Jobcare_data/test.csv')

df_train = add_code(df_train, d_code, h_code, l_code)
df_test = add_code(df_test, d_code, h_code, l_code)

# %%
df_train
# Out:
#             id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  \
# 0            0          True          True          True         False
# 1            1         False         False         False          True
# 2            2         False         False         False          True
# 3            3         False         False         False          True
# 4            4          True          True          True         False
# ...        ...           ...           ...           ...           ...
# 501946  501946         False         False         False          True
# 501947  501947          True          True         False          True
# 501948  501948          True          True          True          True
# 501949  501949          True         False         False          True
# 501950  501950          True          True          True          True
#
#         h_m_match_yn  h_s_match_yn  person_attribute_a  person_attribute_a_1  \
# ...

# %%
import os
import sys
import platform
import random
import math
from typing import List ,Dict, Tuple

import pandas as pd
import numpy as np
 
import sklearn 
from sklearn.model_selection import StratifiedKFold , KFold
from sklearn.metrics import f1_score 

from catboost import Pool,CatBoostClassifier

print(f"- os: {platform.platform()}")
print(f"- python: {sys.version}")
print(f"- pandas: {pd.__version__}")
print(f"- numpy: {np.__version__}")
print(f"- sklearn: {sklearn.__version__}")
# Out:
# - os: Windows-10-10.0.19042-SP0
# - python: 3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]
# - pandas: 1.3.5
# - numpy: 1.21.2
# - sklearn: 0.24.2

# %%
train_data = pd.read_csv('../../220102/DACON/Jobcare_data/train.csv')
test_data = pd.read_csv('../../220102/DACON/Jobcare_data/test.csv')
code_d = pd.read_csv('../../220102/DACON/Jobcare_data/속성_D_코드.csv')
code_h = pd.read_csv('../../220102/DACON/Jobcare_data/속성_H_코드.csv')
code_l = pd.read_csv('../../220102/DACON/Jobcare_data/속성_L_코드.csv')

# %%
code_d
# Out:
#       속성 D 코드  속성 D 세분류코드  속성 D 소분류코드  속성 D 중분류코드  속성 D 대분류코드
# 0           4           4           3           2           1
# 1           5           5           3           2           1
# 2           7           7           6           2           1
# 3           8           8           6           2           1
# 4           9           8           6           2           1
# ...       ...         ...         ...         ...         ...
# 1109     1254        1254        1254        1235        1235
# 1110     1255        1254        1254        1235        1235
# 1111     1256        1254        1254        1235        1235
# 1112     1257        1254        1254        1235        1235
# 1113     1258        1258        1258        1258        1258
#
# [1114 rows x 5 columns]

# %%
train_data.shape, test_data.shape
# Out:
# ((501951, 35), (46404, 34))

# %%
code_d.columns= ["attribute_d","attribute_d_d","attribute_d_s","attribute_d_m","attribute_d_l"]
code_h.columns= ["attribute_h","attribute_h_p","attribute_h_l"]
code_l.columns= ["attribute_l","attribute_l_d","attribute_l_s","attribute_l_m","attribute_l_l"]

# %%
def merge_codes(df:pd.DataFrame,df_code:pd.DataFrame,col:str)->pd.DataFrame:
    df = df.copy()
    df_code = df_code.copy()
    df_code = df_code.add_prefix(f"{col}_")
    df_code.columns.values[0] = col
    return pd.merge(df,df_code,how="left",on=col)

# %%
def preprocess_data(
                    df:pd.DataFrame,is_train:bool = True, cols_merge:List[Tuple[str,pd.DataFrame]] = []  , cols_equi:List[Tuple[str,str]]= [] ,
                    cols_drop:List[str] = ["id","person_prefer_f","person_prefer_g" ,"contents_open_dt"]
                    )->Tuple[pd.DataFrame,np.ndarray]:
    df = df.copy()

    y_data = None
    if is_train:
        y_data = df["target"].to_numpy()
        df = df.drop(columns="target")

    for col, df_code in cols_merge:
        df = merge_codes(df,df_code,col)

    cols = df.select_dtypes(bool).columns.tolist()
    df[cols] = df[cols].astype(int)

    for col1, col2 in cols_equi:
        df[f"{col1}_{col2}"] = (df[col1] == df[col2] ).astype(int)

    df = df.drop(columns=cols_drop)
    return (df , y_data)

# %%
# 소분류 중분류 대분류 속성코드 merge 컬럼명 및 데이터 프레임 리스트
cols_merge = [
              ("person_prefer_d_1" , code_d),
              ("person_prefer_d_2" , code_d),
              ("person_prefer_d_3" , code_d),
              ("contents_attribute_d" , code_d),
              ("person_prefer_h_1" , code_h),
              ("person_prefer_h_2" , code_h),
              ("person_prefer_h_3" , code_h),
              ("contents_attribute_h" , code_h),
              ("contents_attribute_l" , code_l),
]

# 회원 속성과 콘텐츠 속성의 동일한 코드 여부에 대한 컬럼명 리스트
cols_equi = [

    ("contents_attribute_c","person_prefer_c"),
    ("contents_attribute_e","person_prefer_e"),

    ("person_prefer_d_2_attribute_d_s" , "contents_attribute_d_attribute_d_s"),
    ("person_prefer_d_2_attribute_d_m" , "contents_attribute_d_attribute_d_m"),
    ("person_prefer_d_2_attribute_d_l" , "contents_attribute_d_attribute_d_l"),
    ("person_prefer_d_3_attribute_d_s" , "contents_attribute_d_attribute_d_s"),
    ("person_prefer_d_3_attribute_d_m" , "contents_attribute_d_attribute_d_m"),
    ("person_prefer_d_3_attribute_d_l" , "contents_attribute_d_attribute_d_l"),

    ("person_prefer_h_1_attribute_h_p" , "contents_attribute_h_attribute_h_p"),
    ("person_prefer_h_2_attribute_h_p" , "contents_attribute_h_attribute_h_p"),
    ("person_prefer_h_3_attribute_h_p" , "contents_attribute_h_attribute_h_p"),

]

# 학습에 필요없는 컬럼 리스트
cols_drop = ["id","person_prefer_f","person_prefer_g" ,"contents_open_dt", "contents_rn" ]

# %%
x_train, y_train = preprocess_data(train_data, cols_merge = cols_merge , cols_equi= cols_equi , cols_drop = cols_drop)
x_test, _ = preprocess_data(test_data,is_train = False, cols_merge = cols_merge , cols_equi= cols_equi  , cols_drop = cols_drop)
x_train.shape , y_train.shape , x_test.shape
# Out:
# ((501951, 68), (501951,), (46404, 68))

# %%
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Conv1D
from keras.callbacks import ModelCheckpoint, EarlyStopping

import matplotlib.pyplot as plt
import os
import numpy

# %% [markdown]
# model = Sequential()
# model.add(Conv1D(32, kernel_size=1, input_shape=(1, 68), activation='relu'))
# model.add(Conv1D(64, 1, activation='relu'))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(10, activation='softmax'))
#
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %% [markdown]
# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 1), input_shape=(1, 68), activation='relu'))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(10, activation='softmax'))
#
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %% [markdown]
# history = model.fit(TRAIN, yTRAIN,
#                     validation_data=(TRAIN, yTRAIN),
#                     epochs=3, batch_size=200, verbose=0)
#
# print('\nAccuracy: {:.4f}'.format(model.evaluate(X_validation, Y_validation)[1]))
#
# y_vloss = history.history['val_loss']
# y_loss = history.history['loss']
#
# x_len = numpy.arange(len(y_loss))
# plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
# plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
#
# plt.legend(loc='upper right')
# plt.grid()
# plt.xlabel('epoch')
# plt.ylabel('loss')
# plt.show()

# %%
from sklearn.model_selection import KFold
kf = KFold()

# %%
x_data_set = x_train
y_data_set = y_train

# %%
model = Sequential()
model.add(Conv1D(32, kernel_size=1, input_shape=(68,1), activation='relu'))
model.add(Conv1D(64, 1, activation='relu'))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d (Conv1D)              (None, 68, 32)            64
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 68, 64)            2112
# _________________________________________________________________
# dropout (Dropout)            (None, 68, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 4352)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               557184
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# ...

# %%
for train_idx, val_idx in kf.split(x_train):
    x_train = x_data_set.loc[train_idx].values
    x_train = x_train.reshape(x_train.shape[0], 68, 1)
    y_train = y_data_set[train_idx]
    y_train = y_train.reshape(y_train.shape[0], 1)
    x_val = x_data_set.loc[train_idx].values
    x_val = x_val.reshape(x_val.shape[0], 68, 1)
    y_val = y_data_set[train_idx]
    y_val = y_val.reshape(y_val.shape[0], 1)
    
#     TRAIN = TRAIN.values
#     TRAIN = TRAIN.reshape(TRAIN.shape[0], 68, 1)
#     yTRAIN = yTRAIN.reshape(yTRAIN.shape[0], 1)

    history = model.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=10, batch_size=100)

    print('\nAccuracy: {:.4f}'.format(model.evaluate(x_val, y_val)[1]))

    y_vloss = history.history['val_loss']
    y_loss = history.history['loss']

    x_len = numpy.arange(len(y_loss))
    plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
    plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")

    plt.legend(loc='upper right')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()
# Out:
# Epoch 1/10
# 4016/4016 [==============================] - 37s 7ms/step - loss: 0.0000e+00 - accuracy: 0.5322 - val_loss: 0.0000e+00 - val_accuracy: 0.5322
# Epoch 2/10
# 4016/4016 [==============================] - 29s 7ms/step - loss: 0.0000e+00 - accuracy: 0.5322 - val_loss: 0.0000e+00 - val_accuracy: 0.5322
# Epoch 3/10
# 4016/4016 [==============================] - 29s 7ms/step - loss: 0.0000e+00 - accuracy: 0.5322 - val_loss: 0.0000e+00 - val_accuracy: 0.5322
# Epoch 4/10
# 4016/4016 [==============================] - 29s 7ms/step - loss: 0.0000e+00 - accuracy: 0.5322 - val_loss: 0.0000e+00 - val_accuracy: 0.5322
# Epoch 5/10
# 4016/4016 [==============================] - 29s 7ms/step - loss: 0.0000e+00 - accuracy: 0.5322 - val_loss: 0.0000e+00 - val_accuracy: 0.5322
# Epoch 6/10
# 4016/4016 [==============================] - 29s 7ms/step - loss: 0.0000e+00 - accuracy: 0.5322 - val_loss: 0.0000e+00 - val_accuracy: 0.5322
# Epoch 7/10
# ...

# %%
import tensorflow as tf
model = Sequential()
model.add(Conv1D(32, kernel_size=1, input_shape=(68,1), activation='relu'))
model.add(Conv1D(64, 1, activation='relu'))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

model.compile(loss=tf.keras.losses.BinaryCrossentropy,
              optimizer='adam',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_4 (Conv1D)            (None, 68, 32)            64
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 68, 64)            2112
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 68, 64)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4352)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               557184
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# ...

# %%
for train_idx, val_idx in kf.split(x_train):
    x_train = x_data_set.loc[train_idx].values
    x_train = x_train.reshape(x_train.shape[0], 68, 1)
    y_train = y_data_set[train_idx]
    y_train = y_train.reshape(y_train.shape[0], 1)
    x_val = x_data_set.loc[train_idx].values
    x_val = x_val.reshape(x_val.shape[0], 68, 1)
    y_val = y_data_set[train_idx]
    y_val = y_val.reshape(y_val.shape[0], 1)
    
#     TRAIN = TRAIN.values
#     TRAIN = TRAIN.reshape(TRAIN.shape[0], 68, 1)
#     yTRAIN = yTRAIN.reshape(yTRAIN.shape[0], 1)

    history = model.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=10, batch_size=100)

    print('\nAccuracy: {:.4f}'.format(model.evaluate(x_val, y_val)[1]))

    y_vloss = history.history['val_loss']
    y_loss = history.history['loss']

    x_len = numpy.arange(len(y_loss))
    plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
    plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")

    plt.legend(loc='upper right')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12484/3376921865.py in <module>
#      13 #     yTRAIN = yTRAIN.reshape(yTRAIN.shape[0], 1)
#      14
# ---> 15     history = model.fit(x_train, y_train,
#      16                         validation_data=(x_val, y_val),
#      17                         epochs=10, batch_size=100)
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# ...

# %% [markdown]
# Model #2 - ADD LSTM

# %%
from tensorflow.keras import layers
model2 = Sequential()
model2.add(Conv1D(32, kernel_size=1, input_shape=(68,1), activation='relu'))
model2.add(Conv1D(64, 1, activation='relu'))
model2.add(layers.LSTM(128))
model2.add(Dropout(0.25))
model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(1, activation='softmax'))

model2.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_8 (Conv1D)            (None, 68, 32)            64
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 68, 64)            2112
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               98816
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# ...

# %%
for train_idx, val_idx in kf.split(x_data_set):
    x_train = x_data_set.loc[train_idx].values
    x_train = x_train.reshape(x_train.shape[0], 68, 1)
    y_train = y_data_set[train_idx]
    y_train = y_train.reshape(y_train.shape[0], 1)
    x_val = x_data_set.loc[train_idx].values
    x_val = x_val.reshape(x_val.shape[0], 68, 1)
    y_val = y_data_set[train_idx]
    y_val = y_val.reshape(y_val.shape[0], 1)
    
#     TRAIN = TRAIN.values
#     TRAIN = TRAIN.reshape(TRAIN.shape[0], 68, 1)
#     yTRAIN = yTRAIN.reshape(yTRAIN.shape[0], 1)

    history2 = model2.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=10, batch_size=100)

    print('\nAccuracy: {:.4f}'.format(model2.evaluate(x_val, y_val)[1]))

    y_vloss = history2.history['val_loss']
    y_loss = history2.history['loss']

    x_len = numpy.arange(len(y_loss))
    plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
    plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")

    plt.legend(loc='upper right')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()
# Out:
# Epoch 1/10
# 4016/4016 [==============================] - 45s 11ms/step - loss: 0.4678 - accuracy: 0.5322 - val_loss: 0.6301 - val_accuracy: 0.3699
# Epoch 2/10
# 4016/4016 [==============================] - 45s 11ms/step - loss: 0.4678 - accuracy: 0.5322 - val_loss: 0.6301 - val_accuracy: 0.3699
# Epoch 3/10
# 4016/4016 [==============================] - 46s 11ms/step - loss: 0.4678 - accuracy: 0.5322 - val_loss: 0.6301 - val_accuracy: 0.3699
# Epoch 4/10
# 4016/4016 [==============================] - 45s 11ms/step - loss: 0.4678 - accuracy: 0.5322 - val_loss: 0.6301 - val_accuracy: 0.3699
# Epoch 5/10
# 4016/4016 [==============================] - 46s 11ms/step - loss: 0.4678 - accuracy: 0.5322 - val_loss: 0.6301 - val_accuracy: 0.3699
# Epoch 6/10
# 4016/4016 [==============================] - 45s 11ms/step - loss: 0.4678 - accuracy: 0.5322 - val_loss: 0.6301 - val_accuracy: 0.3699
# Epoch 7/10
# ...

# %%
from tensorflow.keras import layers
model2 = Sequential()
model2.add(Conv1D(32, kernel_size=1, input_shape=(68,1), activation='relu'))
model2.add(layers.LSTM(128, return_sequences=True))
model2.add(Conv1D(64, 1, activation='relu'))
model2.add(layers.LSTM(128))
model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dense(1, activation='softmax'))

model2.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])
model2.summary()
for train_idx, val_idx in kf.split(x_data_set):
    x_train = x_data_set.loc[train_idx].values
    x_train = x_train.reshape(x_train.shape[0], 68, 1)
    y_train = y_data_set[train_idx]
    y_train = y_train.reshape(y_train.shape[0], 1)
    x_val = x_data_set.loc[train_idx].values
    x_val = x_val.reshape(x_val.shape[0], 68, 1)
    y_val = y_data_set[train_idx]
    y_val = y_val.reshape(y_val.shape[0], 1)
    
#     TRAIN = TRAIN.values
#     TRAIN = TRAIN.reshape(TRAIN.shape[0], 68, 1)
#     yTRAIN = yTRAIN.reshape(yTRAIN.shape[0], 1)

    history2 = model2.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=10, batch_size=100)

    print('\nAccuracy: {:.4f}'.format(model2.evaluate(x_val, y_val)[1]))

    y_vloss = history2.history['val_loss']
    y_loss = history2.history['loss']

    x_len = numpy.arange(len(y_loss))
    plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
    plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")

    plt.legend(loc='upper right')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_24 (Conv1D)           (None, 68, 32)            64
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 68, 128)           82432
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 68, 64)            8256
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 128)               98816
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 129
# ...

# %%
from tensorflow.keras import layers
model2 = Sequential()
model2.add(Conv1D(32, kernel_size=1, input_shape=(68,1), activation='relu'))
model2.add(Conv1D(64, 1, activation='relu'))
model2.add(layers.LSTM(128, return_sequences=True))
model2.add(layers.LSTM(128))
# model2.add(layers.Attention([128, 1]))
model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dense(1, activation='softmax'))

model2.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])
model2.summary()
for train_idx, val_idx in kf.split(x_data_set):
    x_train = x_data_set.loc[train_idx].values
    x_train = x_train.reshape(x_train.shape[0], 68, 1)
    y_train = y_data_set[train_idx]
    y_train = y_train.reshape(y_train.shape[0], 1)
    x_val = x_data_set.loc[train_idx].values
    x_val = x_val.reshape(x_val.shape[0], 68, 1)
    y_val = y_data_set[train_idx]
    y_val = y_val.reshape(y_val.shape[0], 1)
    
#     TRAIN = TRAIN.values
#     TRAIN = TRAIN.reshape(TRAIN.shape[0], 68, 1)
#     yTRAIN = yTRAIN.reshape(yTRAIN.shape[0], 1)

    history2 = model2.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=10, batch_size=100)

    print('\nAccuracy: {:.4f}'.format(model2.evaluate(x_val, y_val)[1]))

    y_vloss = history2.history['val_loss']
    y_loss = history2.history['loss']

    x_len = numpy.arange(len(y_loss))
    plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
    plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")

    plt.legend(loc='upper right')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12484/3870838323.py in <module>
#       5 model2.add(layers.LSTM(128, return_sequences=True))
#       6 model2.add(layers.LSTM(128))
# ----> 7 model2.add(layers.Attention([128, 1]))
#       8 model2.add(Flatten())
#       9 model2.add(Dense(128, activation='relu'))
#
# c:\users\kimis\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ...
